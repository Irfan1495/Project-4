# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error

# %%
vgsales_df = pd.read_csv("vgsales.csv")
vgsales_df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
vgsales_df = vgsales_df.dropna()

# %%
vgsales_df["Year"] = vgsales_df["Year"].astype(int)
vgsales_df.head()
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
vgsales_df.shape
vgsales_df.info()
vgsales_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  int32
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(5), int32(1), int64(1), object(4)
# memory usage: 1.4+ MB
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16291.000000  16291.000000  16291.000000  16291.000000  16291.000000
# mean    8290.190228   2006.405561      0.265647      0.147731      0.078833
# std     4792.654450      5.832412      0.822432      0.509303      0.311879
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4132.500000   2003.000000      0.000000      0.000000      0.000000
# 50%     8292.000000   2007.000000      0.080000      0.020000      0.000000
# 75%    12439.500000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16291.000000  16291.000000
# mean       0.048426      0.540910
# std        0.190083      1.567345
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.480000
# max       10.570000     82.740000

# %%
vgsales_copy_df = vgsales_df.copy()

# %%
vgsales_copy_df = vgsales_copy_df.drop(columns=['Rank', 'Name', 'Year', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'])
vgsales_copy_df.head()
# Out:
#   Platform         Genre Publisher  NA_Sales
# 0      Wii        Sports  Nintendo     41.49
# 1      NES      Platform  Nintendo     29.08
# 2      Wii        Racing  Nintendo     15.85
# 3      Wii        Sports  Nintendo     15.75
# 4       GB  Role-Playing  Nintendo     11.27

# %%
vgsales_copy_df_encoded = pd.get_dummies(vgsales_copy_df, columns=['Platform', 'Genre', 'Publisher'])
vgsales_copy_df_encoded.head()
# Out:
#    NA_Sales  Platform_2600  Platform_3DO  Platform_3DS  Platform_DC  \
# 0     41.49          False         False         False        False
# 1     29.08          False         False         False        False
# 2     15.85          False         False         False        False
# 3     15.75          False         False         False        False
# 4     11.27          False         False         False        False
#
#    Platform_DS  Platform_GB  Platform_GBA  Platform_GC  Platform_GEN  ...  \
# 0        False        False         False        False         False  ...
# 1        False        False         False        False         False  ...
# 2        False        False         False        False         False  ...
# 3        False        False         False        False         False  ...
# 4        False         True         False        False         False  ...
#
#    Publisher_Zushi Games  Publisher_bitComposer Games  \
# 0                  False                        False
# 1                  False                        False
# 2                  False                        False
# 3                  False                        False
# 4                  False                        False
#
#    Publisher_dramatic create  Publisher_fonfun  Publisher_iWin  \
# 0                      False             False           False
# 1                      False             False           False
# 2                      False             False           False
# 3                      False             False           False
# 4                      False             False           False
#
#    Publisher_id Software  Publisher_imageepoch Inc.  \
# 0                  False                      False
# 1                  False                      False
# 2                  False                      False
# 3                  False                      False
# 4                  False                      False
#
#    Publisher_inXile Entertainment  Publisher_mixi, Inc  Publisher_responDESIGN
# 0                           False                False                   False
# 1                           False                False                   False
# 2                           False                False                   False
# 3                           False                False                   False
# 4                           False                False                   False
#
# [5 rows x 620 columns]

# %%
y = vgsales_copy_df_encoded['NA_Sales']
X = vgsales_copy_df_encoded.drop(columns='NA_Sales')

# %%
X.head()
# Out:
#    Platform_2600  Platform_3DO  Platform_3DS  Platform_DC  Platform_DS  \
# 0          False         False         False        False        False
# 1          False         False         False        False        False
# 2          False         False         False        False        False
# 3          False         False         False        False        False
# 4          False         False         False        False        False
#
#    Platform_GB  Platform_GBA  Platform_GC  Platform_GEN  Platform_GG  ...  \
# 0        False         False        False         False        False  ...
# 1        False         False        False         False        False  ...
# 2        False         False        False         False        False  ...
# 3        False         False        False         False        False  ...
# 4         True         False        False         False        False  ...
#
#    Publisher_Zushi Games  Publisher_bitComposer Games  \
# 0                  False                        False
# 1                  False                        False
# 2                  False                        False
# 3                  False                        False
# 4                  False                        False
#
#    Publisher_dramatic create  Publisher_fonfun  Publisher_iWin  \
# 0                      False             False           False
# 1                      False             False           False
# 2                      False             False           False
# 3                      False             False           False
# 4                      False             False           False
#
#    Publisher_id Software  Publisher_imageepoch Inc.  \
# 0                  False                      False
# 1                  False                      False
# 2                  False                      False
# 3                  False                      False
# 4                  False                      False
#
#    Publisher_inXile Entertainment  Publisher_mixi, Inc  Publisher_responDESIGN
# 0                           False                False                   False
# 1                           False                False                   False
# 2                           False                False                   False
# 3                           False                False                   False
# 4                           False                False                   False
#
# [5 rows x 619 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
print("train size X : ",X_train.shape)
print("train size y : ",y_train.shape)
print("test size X : ",X_test.shape)
print("test size y : ",y_test.shape)
# Out:
# train size X :  (12218, 619)
# train size y :  (12218,)
# test size X :  (4073, 619)
# test size y :  (4073,)

# %%
scaler = StandardScaler()

X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)

X_test_scaled = X_scaler.transform(X_test)

# %%
model = LinearRegression()
lr_model = model.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 8.732663974050115e+22
